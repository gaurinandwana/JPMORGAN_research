# %% [markdown]
# <a href="https://colab.research.google.com/github/gaurinandwana/JPMORGAN_research/blob/main/fico_quantization_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'mortgage_book.csv' not found. Generating standardized synthetic data...

=============================================
      FINAL FICO RATING MAP GENERATED
=============================================
Note: Lower Rating index implies better credit score.

Rating 1: FICO Range [651 - 850] -> Observed PD: 12.01%
Rating 2: FICO Range [601 - 650] -> Observed PD: 37.47%
Rating 3: FICO Range [551 - 600] -> Observed PD: 61.16%
Rating 4: FICO Range [501 - 550] -> Observed PD: 80.37%
Rating 5: FICO Range [300 - 500] -> Observed PD: 92.51%
=============================================
